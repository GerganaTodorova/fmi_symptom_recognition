# %%
def illnessRules(illnessType):
    
    #прилагателно(опц.) + заболяването, пример:силно и остро главоболие, силно остро главоболие
    rule1 = [{'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},
             {'ENT_TYPE': illnessType, 'OP': '+'}]
    
    #прилагателно(опц.) + заболяването + предлог + (възможно прилаг + орган) + прилагателно(опц.) + орган  
    rule2 = [{'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': illnessType, 'OP': '+'},
             {'POS': 'ADP', 'OP': '+'},
             {'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': 'ORGAN', 'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADP', 'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    #прилагателно(опц.) + заболяването + "u"(опц.)  + предлог(опц.) + прилагателно(опц.) + орган  
    #пример: заболяване "загуба на вкус" -> загуба на вкус и обоняние
    rule3 = [{'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': illnessType, 'OP': '+'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADP', 'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    #прилагателно(опц.) + заболяването + "u"(опц.)  + предлог(опц.) + прилагателно(опц.) + система  
    rule4 = [{'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': illnessType, 'OP': '+'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADP', 'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': 'ANATOMICAL_SYSTEM', 'OP': '+'}]
    
    #прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + система  
    rule5 = [{'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},  
             {'ENT_TYPE': illnessType, 'OP': '+'},
             {'POS': 'ADP', 'OP': '+'},
             {'POS': 'ADJ',  'OP': '*'},
             {'LEMMA': "и",  'OP': '*'},
             {'POS': 'ADJ',  'OP': '*'},   
             {'ENT_TYPE': 'ANATOMICAL_SYSTEM', 'OP': '+'}]
             
    return [rule1, rule2, rule3, rule4]

# %%
def negationIllnessRules(illnessType): 
    anotherIllnessType = "COMPLAINT"
    if(illnessType == "COMPLAINT"):
        anotherIllnessType = "SYMPTOM"
    
    # отрицание + прилагателно(опц.) + заболяването, пример:не изпитва силно и остро главоболие
    rule1 = [{'ENT_TYPE':  'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + орган  
    rule2 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + + прилагателно(опц.) + орган +  прилагателно(опц.) + заболяването
    rule3 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': 'ORGAN', 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'}]
                
    # отрицание + прилагателно(опц.) + заболяването +  прилагателно(опц.) + заболяването + предлог + + прилагателно(опц.) + орган
    rule4 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването +  прилагателно(опц.) + заболяването
    rule5 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + орган +  
    #    прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + орган
    rule6 = [{'ENT_TYPE':'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + "и"  
    #    прилагателно(опц.) + заболяването (от другия вид - ако искаме симтоми то тук ще е оплаквания)
    rule7 =[{'ENT_TYPE':  'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': anotherIllnessType, 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + орган + "и"  
    #    прилагателно(опц.) + заболяването (от другия вид - ако искаме симтоми то тук ще е оплаквания)
    rule8 =[{'ENT_TYPE':  'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': anotherIllnessType, 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + орган + "и"  
    #  + прилагателно(опц.) + заболяването (от другия вид - ако искаме симтоми то тук ще е оплаквания) 
    # + предлог + прилагателно(опц.) + орган + "и" 
    rule9 =[{'ENT_TYPE':  'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': anotherIllnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + прилагателно(опц.) + система  
    rule10 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': 'ANATOMICAL_SYSTEM', 'OP': '+'}]
    
    # отрицание + прилагателно(опц.) + заболяването + предлог + + прилагателно(опц.) + система +  прилагателно(опц.) + заболяването
    rule11 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': 'ANATOMICAL_SYSTEM', 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'}]
                
    # отрицание + прилагателно(опц.) + заболяването +  прилагателно(опц.) + заболяването + предлог + + прилагателно(опц.) + система
    rule12 = [{'ENT_TYPE': 'NEGATION', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': illnessType, 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'},
               {'POS': 'ADJ',  'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'POS': 'ADJ',  'OP': '*'},  
               {'ENT_TYPE': 'ANATOMICAL_SYSTEM', 'OP': '+'}]
    
    return [rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, rule12]
