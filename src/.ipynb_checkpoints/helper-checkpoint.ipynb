# %%
# function for display options - describes color options for visualizing the named entities
def getDisplayOptions():

    entities = ["ORGAN", "ANATOMICAL_SYSTEM", "SYMPTOM", "COMPLAINT", "FAMILY", "RISK_FACTOR", "NEGATION", "FAMILY_HISTORY_SYNONYM", "NO_COMPLAINT", "NO_SYMPTOM", "FAMILY_HISTORY", "NO_RISK_FACTOR"]
    
    colors = {"ORGAN":"#F9E79F", "ANATOMICAL_SYSTEM":"#6fcbf7", "SYMPTOM":"#F4D03F", 
              "FAMILY":"#faa0eb", "RISK_FACTOR":"#f8717d", "COMPLAINT":"#A9DFBF", "NEGATION":"#9FB1F9", "FAMILY_HISTORY_SYNONYM":"#BFCC35",
              "NO_COMPLAINT":"#9999CC", "NO_SYMPTOM":"#D0CFFF", "FAMILY_HISTORY":"#C6C699", "NO_RISK_FACTOR":"#FCC6CB"}
    
    options = {"ents": entities, "colors": colors}
    
    return options

# %%
def matcherRulesForFamilyHistory(): 
    # примери: майка и баща с АХ, сестра майка и баща : ах , сестра майка и баща : АХ диабет и ССЗ
    rule1 = [{'ENT_TYPE': 'FAMILY', 'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'ENT_TYPE': 'FAMILY', 'OP': '+'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'LEMMA': "с",  'OP': '*'},
               {'LEMMA': "със",  'OP': '*'},
               {'LEMMA': "за",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '+'}]
    
    #примери: баща с рак на простатата, баща и брат - рак на простатата (едно заболяване + огран)
    rule2 = [{'ENT_TYPE': 'FAMILY', 'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'ENT_TYPE': 'FAMILY', 'OP': '+'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'LEMMA': "с",  'OP': '*'},
               {'LEMMA': "със",  'OP': '*'},
               {'LEMMA': "за",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    #примери: фамилна обремененост за АХ, фамилна обремененост за АХ ССЗ и рак
    rule3 =  [{'ENT_TYPE': 'FAMILY_HISTORY_SYNONYM', 'OP': '+'},
               {'LEMMA': "за",  'OP': '*'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'ENT_TYPE':  'SYMPTOM', 'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '+'}]
   
    #примери: фамилна анамнеза - рак на гърдата
    rule4 = [{'ENT_TYPE': 'FAMILY_HISTORY_SYNONYM', 'OP': '+'},
               {'LEMMA': "за",  'OP': '*'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    #примери: АХ - баща и майка. АХ : баща
    rule5 =  [{'ENT_TYPE': 'SYMPTOM', 'OP': '+'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'ENT_TYPE': 'FAMILY', 'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'ENT_TYPE': 'FAMILY', 'OP': '+'}]
    
    #примери: рак на черния дроб - баща и майка, рак на черния дроб : баща
    rule6 =  [{'ENT_TYPE': 'SYMPTOM', 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'ENT_TYPE': 'FAMILY', 'OP': '*'},
               {'LEMMA': "и",  'OP': '*'},
               {'ENT_TYPE': 'FAMILY', 'OP': '+'}]
    
    #примери: обременена за диабет, обременен за диабет, обременен за : диабет, обременен - диабет, обременен : диабет
    rule7 =  [{'LEMMA': "обременя-(се)",  'OP': '+'},
               {'LEMMA': "за",  'OP': '*'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '+'}]
    
    #примери: обременена за рак на черния дроб, обременена за рак на черния дроб
    rule8 =  [{'LEMMA': "обременя-(се)",  'OP': '+'},
               {'LEMMA': "за",  'OP': '*'},
               {'LEMMA': "-",  'OP': '*'},
               {'LEMMA': ":",  'OP': '*'},
               {'ENT_TYPE': 'SYMPTOM', 'OP': '+'},
               {'POS': 'ADP', 'OP': '+'}, 
               {'ENT_TYPE': 'ORGAN', 'OP': '+'}]
    
    return [rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8]
